# %%
import numpy as np
import cv2 as cv

# %%
img = cv.imread("/content/jigsaw.jpg")

# %%
img = cv.imread("jigsaw.jpg")

part1 = img[150:330, 515:700]
part1 = cv.flip(part1, 1)

img[150:330, 515:700] = part1

part2 = img[370:420, 370:795]
part2 = cv.flip(part2, 0)

img[370:420, 370:795] = part2

part3 = img[0:200, 0:190]


part4 = img[200:410, 0:190]
part4 = cv.flip(part4, 0)

img[200:400, 0:190] = part3
img[0:210, 0:190] = part4

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=797x421 at 0x7F16CD6935B0>
